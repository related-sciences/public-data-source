# %% [markdown]
# ## MedGen Mode of Inheritance (MOI) Concept Selection
#
# Find MedGen concepts for inheritance based on HPO mappings.

# %% [markdown]
# ### Group HPO MOI Concepts
#
# - HPO MOI: https://hpo.jax.org/app/browse/term/HP:0000005 ("hierarchy" on the left).
# - OLS: https://www.ebi.ac.uk/ols/ontologies/hp/terms?iri=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FHP_0000005&viewMode=All&siblings=true
# - Children: http://www.ebi.ac.uk/ols/api/ontologies/hp/descendants?id=HP:0000005&size=500
#
# **NOTE**: In the future, use this instead: https://colab.research.google.com/drive/1TWyVw164bkY4fjodgQ49rZdvTmy9wVyN?usp=sharing

# %%
import requests
import json
url = 'http://www.ebi.ac.uk/ols/api/ontologies/hp/descendants?id=HP:0000005&size=500'
r = requests.get(url).json()

# %%
moi_concepts = {}
for t in r['_embedded']['terms']:
    print(t['iri'], t['label'])
    typ = None
    if 'dominant' in t['label'].lower():
        typ = 'dominant'
    elif 'recessive' in t['label'].lower():
        typ = 'recessive'
    else:
        continue
    if typ not in moi_concepts:
        moi_concepts[typ] = []
    moi_concepts[typ].append(t['iri'].split('/')[-1].replace('_', ':'))
# Out:
# http://purl.obolibrary.org/obo/HP_0000006 Autosomal dominant inheritance
# http://purl.obolibrary.org/obo/HP_0012275 Autosomal dominant inheritance with maternal imprinting
# http://purl.obolibrary.org/obo/HP_0012274 Autosomal dominant inheritance with paternal imprinting
# http://purl.obolibrary.org/obo/HP_0001470 Sex-limited autosomal dominant
# http://purl.obolibrary.org/obo/HP_0001475 Male-limited autosomal dominant
# http://purl.obolibrary.org/obo/HP_0001444 Autosomal dominant somatic cell mutation
# http://purl.obolibrary.org/obo/HP_0001452 Autosomal dominant contiguous gene syndrome
# http://purl.obolibrary.org/obo/HP_0025352 Autosomal dominant germline de novo mutation
# http://purl.obolibrary.org/obo/HP_0000007 Autosomal recessive inheritance
# http://purl.obolibrary.org/obo/HP_0031362 Sex-limited autosomal recessive inheritance
# http://purl.obolibrary.org/obo/HP_0032113 Semidominant mode of inheritance
# http://purl.obolibrary.org/obo/HP_0010985 Gonosomal inheritance
# http://purl.obolibrary.org/obo/HP_0001450 Y-linked inheritance
# http://purl.obolibrary.org/obo/HP_0001417 X-linked inheritance
# http://purl.obolibrary.org/obo/HP_0001423 X-linked dominant inheritance
# http://purl.obolibrary.org/obo/HP_0001419 X-linked recessive inheritance
# http://purl.obolibrary.org/obo/HP_0032382 Uniparental disomy
# http://purl.obolibrary.org/obo/HP_0032384 Uniparental isodisomy
# http://purl.obolibrary.org/obo/HP_0032383 Uniparental heterodisomy
# http://purl.obolibrary.org/obo/HP_0003743 Genetic anticipation
# http://purl.obolibrary.org/obo/HP_0003744 Genetic anticipation with paternal anticipation bias
# http://purl.obolibrary.org/obo/HP_0003745 Sporadic
# http://purl.obolibrary.org/obo/HP_0001466 Contiguous gene syndrome
# http://purl.obolibrary.org/obo/HP_0001425 Heterogeneous
# http://purl.obolibrary.org/obo/HP_0001426 Multifactorial inheritance
# http://purl.obolibrary.org/obo/HP_0010983 Oligogenic inheritance
# http://purl.obolibrary.org/obo/HP_0010984 Digenic inheritance
# http://purl.obolibrary.org/obo/HP_0010982 Polygenic inheritance
# http://purl.obolibrary.org/obo/HP_0001427 Mitochondrial inheritance
# http://purl.obolibrary.org/obo/HP_0001428 Somatic mutation
# http://purl.obolibrary.org/obo/HP_0001442 Somatic mosaicism

# %%
moi_concepts
# Out:
# {'dominant': ['HP:0000006',
#   'HP:0012275',
#   'HP:0012274',
#   'HP:0001470',
#   'HP:0001475',
#   'HP:0001444',
#   'HP:0001452',
#   'HP:0025352',
#   'HP:0032113',
#   'HP:0001423'],
#  'recessive': ['HP:0000007', 'HP:0031362', 'HP:0001419']}

# %% [markdown]
# ### Extract MOI from MedGen

# %%
url = 'https://ftp.ncbi.nlm.nih.gov/pub/medgen/MedGen_HPO_Mapping.txt.gz'
# !wget -P /tmp $url
# !gzip -dc /tmp/MedGen_HPO_Mapping.txt.gz | head
# Out:
# --2020-06-19 11:56:21--  https://ftp.ncbi.nlm.nih.gov/pub/medgen/MedGen_HPO_Mapping.txt.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.10, 2607:f220:41e:250::10
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 288969 (282K) [application/x-gzip]
# Saving to: ‘/tmp/MedGen_HPO_Mapping.txt.gz.1’
#
# MedGen_HPO_Mapping. 100%[===================>] 282.20K  1.43MB/s    in 0.2s
#
# 2020-06-19 11:56:21 (1.43 MB/s) - ‘/tmp/MedGen_HPO_Mapping.txt.gz.1’ saved [288969/288969]
#
# #CUI|SDUI|HpoStr|MedGenStr|MedGenStr_SAB|STY|
# C0444868|HP:0000001|All|All|HPO|Quantitative Concept|
# C4025901|HP:0000002|Abnormality of body height|Abnormality of body height|GTR|Finding|
# C3714581|HP:0000003|Multicystic kidney dysplasia|Multicystic kidney dysplasia|GTR|Disease or Syndrome|
# C1708511|HP:0000005|Mode of inheritance|Mode of inheritance|HPO|Genetic Function|
# C0443147|HP:0000006|Autosomal dominant inheritance|Autosomal dominant inheritance|GTR|Intellectual Product|
# C0443147|HP:0000006|Autosomal dominant inheritance|Autosomal dominant inheritance|GTR|Genetic Function|
# C0441748|HP:0000007|Autosomal recessive inheritance|Autosomal recessive inheritance|HPO|Intellectual Product|
# C0441748|HP:0000007|Autosomal recessive inheritance|Autosomal recessive inheritance|HPO|Genetic Function|
# C4025900|HP:0000008|Abnormality of female internal genitalia|Abnormality of female internal genitalia|GTR|Anatomical Abnormality|
#
# gzip: stdout: Broken pipe

# %%
import pandas as pd
df = pd.read_csv('/tmp/MedGen_HPO_Mapping.txt.gz', sep='|')
df.head()
# Out:
#        #CUI        SDUI                          HpoStr  \
# 0  C0444868  HP:0000001                             All
# 1  C4025901  HP:0000002      Abnormality of body height
# 2  C3714581  HP:0000003    Multicystic kidney dysplasia
# 3  C1708511  HP:0000005             Mode of inheritance
# 4  C0443147  HP:0000006  Autosomal dominant inheritance
#
#                         MedGenStr MedGenStr_SAB                   STY  \
# 0                             All           HPO  Quantitative Concept
# 1      Abnormality of body height           GTR               Finding
# 2    Multicystic kidney dysplasia           GTR   Disease or Syndrome
# 3             Mode of inheritance           HPO      Genetic Function
# 4  Autosomal dominant inheritance           GTR  Intellectual Product
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
cids = [v for vs in moi_concepts.values() for v in vs]
dfc = df[df['SDUI'].isin(cids)]
dfc
# Out:
#            #CUI        SDUI  \
# 4      C0443147  HP:0000006
# 5      C0443147  HP:0000006
# 6      C0441748  HP:0000007
# 7      C0441748  HP:0000007
# 1187   C1845977  HP:0001419
# 1189   C1847879  HP:0001423
# 1204   C4025781  HP:0001444
# 1209   C4025777  HP:0001452
# 1221   C4025767  HP:0001470
# 1225   C4025764  HP:0001475
# 9304   C4022976  HP:0012274
# 9305   C4022975  HP:0012275
# 10369  C4476722  HP:0025352
# 11945  C4531174  HP:0031362
# 12662  CN259289  HP:0032113
#
#                                                   HpoStr  \
# 4                         Autosomal dominant inheritance
# 5                         Autosomal dominant inheritance
# 6                        Autosomal recessive inheritance
# 7                        Autosomal recessive inheritance
# 1187                      X-linked recessive inheritance
# 1189                       X-linked dominant inheritance
# 1204            Autosomal dominant somatic cell mutation
# 1209         Autosomal dominant contiguous gene syndrome
# 1221                      Sex-limited autosomal dominant
# 1225                     Male-limited autosomal dominant
# 9304   Autosomal dominant inheritance with paternal i...
# 9305   Autosomal dominant inheritance with maternal i...
# 10369       Autosomal dominant germline de novo mutation
# 11945        Sex-limited autosomal recessive inheritance
# 12662                   Semidominant mode of inheritance
#
#                                                MedGenStr MedGenStr_SAB  \
# 4                         Autosomal dominant inheritance           GTR
# 5                         Autosomal dominant inheritance           GTR
# 6                        Autosomal recessive inheritance           HPO
# 7                        Autosomal recessive inheritance           HPO
# 1187                      X-linked recessive inheritance           GTR
# 1189                       X-linked dominant inheritance           HPO
# 1204            Autosomal dominant somatic cell mutation           HPO
# 1209         Autosomal dominant contiguous gene syndrome           HPO
# 1221                      Sex-limited autosomal dominant           HPO
# 1225                     Male-limited autosomal dominant           HPO
# 9304   Autosomal dominant inheritance with paternal i...           HPO
# 9305   Autosomal dominant inheritance with maternal i...           HPO
# 10369       Autosomal dominant germline de novo mutation           HPO
# 11945        Sex-limited autosomal recessive inheritance           HPO
# 12662                   Semidominant mode of inheritance           HPO
#
#                                  STY  Unnamed: 6
# 4               Intellectual Product         NaN
# 5                   Genetic Function         NaN
# 6               Intellectual Product         NaN
# 7                   Genetic Function         NaN
# 1187                         Finding         NaN
# 1189                         Finding         NaN
# 1204                Genetic Function         NaN
# 1209             Disease or Syndrome         NaN
# 1221                Genetic Function         NaN
# 1225                Genetic Function         NaN
# 9304   Cell or Molecular Dysfunction         NaN
# 9305                Genetic Function         NaN
# 10369               Genetic Function         NaN
# 11945               Genetic Function         NaN
# 12662               Genetic Function         NaN

# %%
assert dfc['SDUI'].nunique() == len(cids)
len(dfc), dfc['SDUI'].nunique(), len(cids)
# Out:
# (15, 13, 13)
